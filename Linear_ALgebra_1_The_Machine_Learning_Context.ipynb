# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/Nov23_MathsForML/blob/main/Linear_ALgebra_1_The_Machine_Learning_Context.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# x![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Download Data:

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/030/385/original/fruits.csv?1680749521 -O fruits.csv
# Out:
# --2023-11-06 17:48:52--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/030/385/original/fruits.csv?1680749521
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.172.139.46, 18.172.139.61, 18.172.139.94, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.172.139.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219 [text/plain]
# Saving to: ‘fruits.csv’
#
# fruits.csv          100%[===================>]     219  --.-KB/s    in 0s
#
# 2023-11-06 17:48:53 (66.1 MB/s) - ‘fruits.csv’ saved [219/219]

# %%
import pandas as pd
df = pd.read_csv('fruits.csv')
df.head()
# Out:
#    weight  diameter   color       fruit
# 0     4.0       3.0  orange  trangerine
# 1     4.2       4.0  orange  trangerine
# 2     3.8       3.5  orange  trangerine
# 3     4.5       3.8  orange  trangerine
# 4     2.8       5.0  orange      orange

# %%
df.fruit.value_counts()
# Out:
# trangerine    4
# orange        4
# Name: fruit, dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x='weight', y = 'diameter', hue='fruit', data=df)
# Out:
# <Axes: xlabel='weight', ylabel='diameter'>

# %% [markdown]
# - Find the value of m and c to get best fit line

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive

def plot_line(m, c):
    x = np.linspace(2, 5, num=100)  # generate x values
    y = m*x + c  # calculate y values
    # plt.plot(x, y)  # plot the line
    sns.scatterplot(x='weight', y = 'diameter', hue='fruit', data=df)
    plt.plot(x, y)  # plot the line
    # plt.ylim(-50, 50)  # set y-axis limits
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'y = {m}x + {c}')
    plt.show()

interactive_plot = interactive(plot_line, m=(-5, 10, 0.1), c=(-5, 5, 1))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=2.0, description='m', max=10.0, min=-5.0), IntSlider(value=0, descript…

# %% [markdown]
# ### also convert the above code to suit General Equation of Line and find best values of w1, w2 and w0
